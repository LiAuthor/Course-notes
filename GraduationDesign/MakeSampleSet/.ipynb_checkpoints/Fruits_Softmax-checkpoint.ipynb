# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import pathlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
from os import listdir
from os.path import join
data_root_orig="/home/yee/DataSet/dataset/dataset/train"
data_root = pathlib.Path(data_root_orig)
#for item in data_root.iterdir():
    #print(item)

# %%
import random
#获取所有图片的路径
all_image_paths = list(data_root.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]
#将所有路径打乱
random.shuffle(all_image_paths)

image_count = len(all_image_paths)
image_count
# Out:
# 4184

# %%
all_image_paths[:3]
# Out:
# ['/home/yee/DataSet/dataset/dataset/train/freshbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.44.40 PM.png',
#  '/home/yee/DataSet/dataset/dataset/train/freshbanana/translation_Screen Shot 2018-06-12 at 9.56.39 PM.png',
#  '/home/yee/DataSet/dataset/dataset/train/freshbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.41.43 PM.png']

# %%
from PIL import Image

train_images = []
for image in all_image_paths:
    #print((os.path.join(image)))
    with Image.open(os.path.join(image)) as img:
        train_images.append(img)
    
#for i in range(len(all_image_paths)):
#    img=Image.open(all_image_paths[i])
#    train_images.append(img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-85c2024b1fd9> in <module>
#       6     #train_images.append(Image.open(os.path.join(image)))
#       7 for i in range(len(all_image_paths)):
# ----> 8     img=Image.open(all_image_paths[i])
#       9     train_images.append(img)
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode, formats)
#
# OSError: [Errno 24] Too many open files: '/home/yee/DataSet/dataset/dataset/train/freshbanana/rotated_by_60_Screen Shot 2018-06-12 at 10.05.54 PM.png'

# %%
import matplotlib.pyplot as plt

train_labels  = [pathlib.Path(path).parent.name for path in all_image_paths]

plt.figure(figsize=(20,10))
for i in range(20):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(train_labels[i])
plt.show()

# %%
img_height=180
img_width=180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_root,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(180, 180),
  batch_size=32)

class_names = train_ds.class_names
print("\n",class_names)

train_ds
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-d45d8977f4f5> in <module>
#       5   seed=123,
#       6   image_size=(180, 180),
# ----> 7   batch_size=32)
#       8
#       9 class_names = train_ds.class_names
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/keras/preprocessing/image_dataset.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links)
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow/python/keras/preprocessing/dataset_utils.py in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#
# OSError: [Errno 24] Too many open files: '/home/yee/DataSet/dataset/dataset/train'
