# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import pathlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
img_height = 180
img_width = 180
num_classes = 3

data_root_orig = "/home/yee/DataSet/dataset/dataset/train"
data_root = pathlib.Path(data_root_orig)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_root,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(180, 180),
    batch_size=32)

class_names = train_ds.class_names

data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal",
                                                     input_shape=(img_height,
                                                                  img_width,
                                                                  3)),
        layers.experimental.preprocessing.RandomRotation(0.1),
        layers.experimental.preprocessing.RandomZoom(0.1),
    ]
)


def create_model():
    model = Sequential([
        data_augmentation,
        layers.experimental.preprocessing.Rescaling(1./255),
        layers.Conv2D(16, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.MaxPooling2D(),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes)
    ])
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(
                      from_logits=True),
                  metrics=['accuracy'])
    return model
# Out:
# Found 4184 files belonging to 3 classes.
# Using 3348 files for training.

# %%
# data_root_orig="/home/yee/DataSet/flower_photos/sunflowers"
data_root_orig = "/home/yee/DataSet/dataset/dataset/test/freshapples"
data_root = pathlib.Path(data_root_orig)
# 创建模型实例
model = create_model()

# 恢复权重
model.load_weights('/home/yee/GraduationDesign/Model/checkpoints/Fruits/Fruits_checkpoint')

# 遍历文件夹中的每个文件测试
for item in data_root.iterdir():
    # print(item)
    img = keras.preprocessing.image.load_img(
        item, target_size=(img_height, img_width) 
    )
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    
    print(
        "Belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.92 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.80 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 98.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.77 percent confidence.
# Likely belongs to freshapples with a 99.80 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.53 percent confidence.
# Likely belongs to freshapples with a 99.86 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.93 percent confidence.
# Likely belongs to freshapples with a 99.62 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 98.60 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 97.51 percent confidence.
# Likely belongs to freshapples with a 99.61 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.74 percent confidence.
# Likely belongs to freshapples with a 99.83 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.66 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.93 percent confidence.
# Likely belongs to freshapples with a 99.75 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.50 percent confidence.
# Likely belongs to freshapples with a 52.48 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.88 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.85 percent confidence.
# Likely belongs to freshapples with a 99.59 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.92 percent confidence.
# Likely belongs to freshapples with a 99.54 percent confidence.
# Likely belongs to freshapples with a 99.81 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.70 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 93.43 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.83 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.67 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 97.22 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 98.73 percent confidence.
# Likely belongs to freshapples with a 97.88 percent confidence.
# Likely belongs to freshapples with a 96.88 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.93 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.64 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.81 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 99.86 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.66 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.73 percent confidence.
# Likely belongs to freshapples with a 98.49 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.75 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.45 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.64 percent confidence.
# Likely belongs to freshapples with a 97.87 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 98.45 percent confidence.
# Likely belongs to freshapples with a 96.92 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 97.52 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 99.82 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.95 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.85 percent confidence.
# Likely belongs to freshapples with a 99.50 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.95 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.64 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.48 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.87 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 99.22 percent confidence.
# Likely belongs to freshapples with a 95.59 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 99.93 percent confidence.
# Likely belongs to freshapples with a 99.86 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 96.90 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.65 percent confidence.
# Likely belongs to freshapples with a 99.89 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.93 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.95 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.73 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.19 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 99.89 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.92 percent confidence.
# Likely belongs to freshapples with a 64.85 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.84 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 97.64 percent confidence.
# Likely belongs to freshapples with a 98.94 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 99.89 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.70 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.06 percent confidence.
# Likely belongs to freshapples with a 95.28 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 94.25 percent confidence.
# Likely belongs to freshapples with a 99.96 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 98.27 percent confidence.
# Likely belongs to freshapples with a 99.05 percent confidence.
# Likely belongs to freshapples with a 99.95 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.89 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 98.35 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 91.02 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 92.16 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 98.89 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.91 percent confidence.
# Likely belongs to freshapples with a 99.82 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.78 percent confidence.
# Likely belongs to freshapples with a 99.82 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.41 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 98.02 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.87 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.92 percent confidence.
# Likely belongs to freshapples with a 99.94 percent confidence.
# Likely belongs to freshapples with a 99.92 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.83 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.73 percent confidence.
# Likely belongs to freshapples with a 99.39 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 98.89 percent confidence.
# Likely belongs to freshapples with a 99.69 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 98.13 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.90 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.71 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.92 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.89 percent confidence.
# Likely belongs to freshapples with a 98.10 percent confidence.
# Likely belongs to freshapples with a 99.95 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.98 percent confidence.
# Likely belongs to freshapples with a 99.83 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.99 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 99.83 percent confidence.
# Likely belongs to freshapples with a 98.64 percent confidence.
# Likely belongs to freshapples with a 99.97 percent confidence.
# Likely belongs to freshapples with a 99.64 percent confidence.
# Likely belongs to freshapples with a 99.45 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
# Likely belongs to freshapples with a 100.00 percent confidence.
